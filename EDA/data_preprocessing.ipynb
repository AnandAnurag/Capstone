# %%
import os
import json
import progressbar
import math
import pandas as pd
import numpy as np
from pandas import json_normalize
from functools import reduce

# %%
CITIES_FILEPATH = '../Dataset/Location/cities.json'
STATES_FILEPATH = '../Dataset/Location/states.json'
COUNTRIES_FILEPATH = '../Dataset/Location/countries.json'
LOCATION_FILEPATH = '../Dataset/Processed/Locations.csv'
USERS_FILEPATH = '../Dataset/BX-CSV-Dump/BX-Users.csv'
USERS_NORMALIZED_FILEPATH = '../Dataset/Processed/BX-Users.csv'
LOC_FUZZY_MAP_FILEPATH = '../Dataset/Processed/mappings.json'

# %%
def sanitizeNumericData(row, as_types):
    for col in as_types:
        row[col] = int(''.join(filter(str.isdigit, row[col]))) if as_types[col] == 'int64' else row[col]
    return row

# %%
def loadDataframeFromJSON(filepath, key, rename_columns, as_types={}):
    with open(filepath) as f: 
        d = json.load(f)  
    return json_normalize(d[key]).apply(sanitizeNumericData, args=(as_types, ), axis=1).rename(columns=rename_columns)

# %%
if not os.path.exists(LOCATION_FILEPATH):
    cities = loadDataframeFromJSON(CITIES_FILEPATH, 'cities', {'id': 'city_id', 'name': 'city'}, {'id': 'int64', 'state_id': 'int64'})
    states = loadDataframeFromJSON(STATES_FILEPATH, 'states', {'id': 'state_id', 'name': 'state'}, {'id': 'int64','country_id': 'int64'})
    countries = loadDataframeFromJSON(COUNTRIES_FILEPATH, 'countries', {'id': 'country_id', 'sortname': 'country_code', 'phoneCode': 'phone_code', 'name': 'country'})
    locations = cities.merge(states, on='state_id', how="inner").merge(countries, on='country_id', how="inner")
    locations.to_csv(LOCATION_FILEPATH, index=False, index_label=False, columns=['city_id', 'city', 'state_id', 'state', 'country_id', 'country', 'country_code', 'phone_code'])
else:
    locations = pd.read_csv(LOCATION_FILEPATH);

# %%
locations['Location'] = locations['city'] + ", " + locations['state'] + ", " + locations['country']

# %%
locations.head()
# Out:
#    city_id        city  state_id                        state  country_id  \
# 0        1   Bombuflat         1  Andaman and Nicobar Islands         101
# 1        2  Garacharma         1  Andaman and Nicobar Islands         101
# 2        3  Port Blair         1  Andaman and Nicobar Islands         101
# 3        4      Rangat         1  Andaman and Nicobar Islands         101
# 4        5     Addanki         2               Andhra Pradesh         101
#
#   country country_code  phone_code  \
# 0   India           IN          91
# 1   India           IN          91
# 2   India           IN          91
# 3   India           IN          91
# 4   India           IN          91
#
#                                          Location
# 0   Bombuflat, Andaman and Nicobar Islands, India
# 1  Garacharma, Andaman and Nicobar Islands, India
# 2  Port Blair, Andaman and Nicobar Islands, India
# 3      Rangat, Andaman and Nicobar Islands, India
# 4                  Addanki, Andhra Pradesh, India

# %%
def loadNormalizedUsers():
    if not os.path.exists(USERS_NORMALIZED_FILEPATH):
        users = pd.read_csv(USERS_FILEPATH, sep=";")
        users_loc = pd.DataFrame([ x.split(', ', 2)[0:3] for x in users['Location'].tolist() ])
        users_loc.columns = ['city', 'state', 'country']
        users_normalized = pd.concat([users, users_loc], axis=1)
        users_normalized['fuzzy_match'] = np.nan
    else:
        users_normalized = pd.read_csv(USERS_NORMALIZED_FILEPATH, dtype={'fuzzy_match': str, "city": str, "state": str})
    return users_normalized

# %% [markdown]
# users_normalized = loadNormalizedUsers()
# users_normalized.loc[120:140]

# %%
# ! conda install -c conda-forge fuzzywuzzy

# %%
from fuzzywuzzy import fuzz, process

# %%
def getPotentialMatch(city, state):
    booleans = []
    for row in locations.itertuples():
        if fuzz.WRatio(state, row.state) >= 90:
            booleans.append(True)
        else:
            booleans.append(False)
    return booleans

# %%
f = open(LOC_FUZZY_MAP_FILEPATH,)  
mapping = json.load(f)
def fuzzy_match_loc(row):
    index = row.city + "|" + row.state
    if(index not in mapping):
        filters = getPotentialMatch(row.city, row.state);
        potential_matches = locations[filters]
        if potential_matches['Location'].count() > 0:
            row.fuzzy_match = process.extractOne(row.Location, list(potential_matches['Location'].values))[0]
            mapping[index] = row.fuzzy_match
    else:
       row.fuzzy_match  = mapping[index]
    return row

# %%
n = 1000
chunk=0
stop_limit = 1
users_normalized = loadNormalizedUsers()
to_process_users= users_normalized[users_normalized['fuzzy_match'].isna()].fillna('')
total_chunk = to_process_users.shape[0] // n
list_df = [to_process_users[i:i+n] for i in range(0,to_process_users.shape[0],n)]
for df in progressbar.progressbar(list_df, redirect_stdout=True):
    updated_df = df.apply(fuzzy_match_loc, axis=1)
    users_normalized.loc[users_normalized['User-ID'].isin(updated_df['User-ID']), ['fuzzy_match']] = updated_df[['fuzzy_match']]
    users_normalized.to_csv(USERS_NORMALIZED_FILEPATH, index=False, index_label=False)
    saveLocMapping()
    '''
    chunk=chunk+1
    if chunk == stop_limit:
        updated_df.head(20)
        break
    '''
# Out:
# 100% (53 of 53) |#######################| Elapsed Time: 19:16:44 Time: 19:16:44

# %%
updated_df
# Out:
#      User-ID                                           Location Age  \
# 0          1                                 nyc, new york, usa
# 13        14                              mediapolis, iowa, usa
# 17        18             rio de janeiro, rio de janeiro, brazil  25
# 20        21                     ferrol / spain, alabama, spain  46
# 53        54                              eubank, kentucky, usa  44
# 59        60              trieste, friuli venezia giulia, italy
# 64        65                                n/a, n/a, australia
# 83        84                         san diago, california, usa
# 89        90                            powhatan, virginia, usa  42
# 90        91                               toronto/newmarket, ,
# 92        93                               eden, wisconsin, usa  50
# 98        99                           franktown, colorado, usa  42
# 103      104                        foxboro, massachusetts, usa  47
# 109      110                              peoira, illinois, usa
# 111      112                          mexico city, d.f., mexico  32
# 113      114                        ligonier, pennsylvania, usa  57
# 127      128                    allison park, pennsylvania, usa
# 133      134  canberra, australian capital territory, australia
# 139      140          kappelrodeck, baden-wuerttemberg, germany  24
# 145      146                                la, california, usa
# 150      151              darwin, northern territory, australia
# 154      155                                lion, abruzzo, peru
# 155      156              sarajevo, n/a, bosnia and herzegovina  20
# 157      158             nufringen, baden-wuerttemberg, germany  38
# 159      160                              almada, n/a, portugal  20
# 160      161                           lisboa, lisboa, portugal  27
# 171      172             rio de janeiro, rio de janeiro, brazil  66
# 177      178                             rexford, new york, usa  28
# 179      180                         copenhagen n, n/a, denmark
# 181      182                   buitenpost, fryslân, netherlands  36
# 186      187              mcas futenma fpo ap okinawa, n/a, usa  29
# 208      209                             pj, selangor, malaysia  21
# 214      215             port alberni, british columbia, canada  20
# 229      230                                  ny, new york, usa
# 242      243                        arden hills, minnesota, usa
# 245      246                         tananger, rogaland, norway  16
# 246      247                           zografou, athens, greece  23
# 247      248               chilliwack, british columbia, canada  15
# 251      252                        13001 safat, kuwait, kuwait  65
# 256      257                                   quit, quit, quit
# 257      258                                       ljk, lkj, lj
# 259      260                           chisholm, minnesota, usa  51
# 260      261                lonsee, baden-wuerttemberg, germany  45
# 263      264                                taipei, n/a, taiwan  23
# 265      266                           kalgary, alberta, canada
# 267      268                              århus, "n/a", denmark
# 269      270                   tawern, rheinland-pfalz, germany
# 276      277                  dubbo, new south wales, australia  15
# 287      288                              hallowell, maine, usa  19
# 290      291                         ft. collins, colorado, usa
#
#                             city                         state  \
# 0                            nyc                      new york
# 13                    mediapolis                          iowa
# 17                rio de janeiro                rio de janeiro
# 20                ferrol / spain                       alabama
# 53                        eubank                      kentucky
# 59                       trieste         friuli venezia giulia
# 64
# 83                     san diago                    california
# 89                      powhatan                      virginia
# 90             toronto/newmarket                             ,
# 92                          eden                     wisconsin
# 98                     franktown                      colorado
# 103                      foxboro                 massachusetts
# 109                       peoira                      illinois
# 111                  mexico city                          d.f.
# 113                     ligonier                  pennsylvania
# 127                 allison park                  pennsylvania
# 133                     canberra  australian capital territory
# 139                 kappelrodeck            baden-wuerttemberg
# 145                           la                    california
# 150                       darwin            northern territory
# 154                         lion                       abruzzo
# 155                     sarajevo
# 157                    nufringen            baden-wuerttemberg
# 159                       almada
# 160                       lisboa                        lisboa
# 171               rio de janeiro                rio de janeiro
# 177                      rexford                      new york
# 179                 copenhagen n
# 181                   buitenpost                       fryslân
# 186  mcas futenma fpo ap okinawa
# 208                           pj                      selangor
# 214                 port alberni              british columbia
# 229                           ny                      new york
# 242                  arden hills                     minnesota
# 245                     tananger                      rogaland
# 246                     zografou                        athens
# 247                   chilliwack              british columbia
# 251                  13001 safat                        kuwait
# 256                         quit                          quit
# 257                          ljk                           lkj
# 259                     chisholm                     minnesota
# 260                       lonsee            baden-wuerttemberg
# 263                       taipei
# 265                      kalgary                       alberta
# 267                        århus                         "n/a"
# 269                       tawern               rheinland-pfalz
# 276                        dubbo               new south wales
# 287                    hallowell                         maine
# 290                  ft. collins                      colorado
#
#                     country                                      fuzzy_match
# 0                       usa                 Airmont, New York, United States
# 13                      usa                 Cedar Falls, Iowa, United States
# 17                   brazil
# 20                    spain               Fort Payne, Alabama, United States
# 53                      usa                 Ashland, Kentucky, United States
# 59                    italy                             Cona, Venezia, Italy
# 64                australia
# 83                      usa          Agoura Hills, California, United States
# 89                      usa              Alexandria, Virginia, United States
# 90
# 92                      usa                  Adams, Wisconsin, United States
# 98                      usa       Air Force Academy, Colorado, United States
# 103                     usa     Amherst Center, Massachusetts, United States
# 109                     usa                 Addison, Illinois, United States
# 111                  mexico
# 113                     usa       Back Mountain, Pennsylvania, United States
# 127                     usa  Cranberry Township, Pennsylvania, United States
# 133               australia                               Pita, Pita, Guinea
# 139                 germany               Asperg, Baden-Wurttemberg, Germany
# 145                     usa                 Acton, California, United States
# 150               australia                         Kpandae, Northern, Ghana
# 154                    peru                   Alba Adriatica, Abruzzo, Italy
# 155  bosnia and herzegovina
# 157                 germany            Nurtingen, Baden-Wurttemberg, Germany
# 159                portugal
# 160                portugal
# 171                  brazil
# 177                     usa              Amityville, New York, United States
# 179                 denmark
# 181             netherlands
# 186                     usa
# 208                malaysia                       Ampang, Selangor, Malaysia
# 214                  canada
# 229                     usa                 Airmont, New York, United States
# 242                     usa        Brooklyn Center, Minnesota, United States
# 245                  norway                      Stavanger, Rogaland, Norway
# 246                  greece
# 247                  canada
# 251                  kuwait
# 256                    quit                         Abzac, Aquitaine, France
# 257                      lj
# 259                     usa             Albert Lea, Minnesota, United States
# 260                 germany               Kongen, Baden-Wurttemberg, Germany
# 263                  taiwan
# 265                  canada                         Calgary, Alberta, Canada
# 267                 denmark                        Diu, Daman and Diu, India
# 269                 germany                  Mayen, Rheinland-Pfalz, Germany
# 276               australia            West Glamorgan, Wales, United Kingdom
# 287                     usa          Les Ponts-de-Ce, Maine-et-Loire, France
# 290                     usa       Air Force Academy, Colorado, United States

# %%
users_normalized = loadNormalizedUsers()
users_normalized[users_normalized['fuzzy_match'] = '']
# Out:
#         User-ID                                          Location   Age  \
# 0             1                                nyc, new york, usa   NaN
# 13           14                             mediapolis, iowa, usa   NaN
# 17           18            rio de janeiro, rio de janeiro, brazil  25.0
# 20           21                    ferrol / spain, alabama, spain  46.0
# 53           54                             eubank, kentucky, usa  44.0
# ...         ...                                               ...   ...
# 278819   278820                   ninety six, south carolina, usa  59.0
# 278840   278841  llangollen, denbighshire county, united kingdom.   NaN
# 278844   278845                       järvenpää, uusimaa, finland   NaN
# 278847   278848                köln, nordrhein-westfalen, germany   NaN
# 278849   278850                        sergnano, lombardia, italy   NaN
#
#                   city                state          country fuzzy_match
# 0                  nyc             new york              usa         NaN
# 13          mediapolis                 iowa              usa         NaN
# 17      rio de janeiro       rio de janeiro           brazil         NaN
# 20      ferrol / spain              alabama            spain         NaN
# 53              eubank             kentucky              usa         NaN
# ...                ...                  ...              ...         ...
# 278819      ninety six       south carolina              usa         NaN
# 278840      llangollen  denbighshire county  united kingdom.         NaN
# 278844       järvenpää              uusimaa          finland         NaN
# 278847            köln  nordrhein-westfalen          germany         NaN
# 278849        sergnano            lombardia            italy         NaN
#
# [52094 rows x 7 columns]

# %%
len(mapping)
# Out:
# 31388

# %%
def saveLocMapping():
    json_content = json.dumps(mapping)
    f = open(LOC_FUZZY_MAP_FILEPATH,"w")
    f.write(json_content)
    f.close()

# %%
len(users_normalized['Location'])
# Out:
# 278770

# %%
users_normalized[users_normalized['fuzzy_match'].isna()]
# Out:
#         User-ID                                          Location   Age  \
# 0             1                                nyc, new york, usa   NaN
# 13           14                             mediapolis, iowa, usa   NaN
# 17           18            rio de janeiro, rio de janeiro, brazil  25.0
# 20           21                    ferrol / spain, alabama, spain  46.0
# 53           54                             eubank, kentucky, usa  44.0
# ...         ...                                               ...   ...
# 278819   278820                   ninety six, south carolina, usa  59.0
# 278840   278841  llangollen, denbighshire county, united kingdom.   NaN
# 278844   278845                       järvenpää, uusimaa, finland   NaN
# 278847   278848                köln, nordrhein-westfalen, germany   NaN
# 278849   278850                        sergnano, lombardia, italy   NaN
#
#                   city                state          country fuzzy_match
# 0                  nyc             new york              usa         NaN
# 13          mediapolis                 iowa              usa         NaN
# 17      rio de janeiro       rio de janeiro           brazil         NaN
# 20      ferrol / spain              alabama            spain         NaN
# 53              eubank             kentucky              usa         NaN
# ...                ...                  ...              ...         ...
# 278819      ninety six       south carolina              usa         NaN
# 278840      llangollen  denbighshire county  united kingdom.         NaN
# 278844       järvenpää              uusimaa          finland         NaN
# 278847            köln  nordrhein-westfalen          germany         NaN
# 278849        sergnano            lombardia            italy         NaN
#
# [52094 rows x 7 columns]

# %%
locations.head()
# Out:
#    city_id        city  state_id                        state  country_id  \
# 0        1   Bombuflat         1  Andaman and Nicobar Islands         101
# 1        2  Garacharma         1  Andaman and Nicobar Islands         101
# 2        3  Port Blair         1  Andaman and Nicobar Islands         101
# 3        4      Rangat         1  Andaman and Nicobar Islands         101
# 4        5     Addanki         2               Andhra Pradesh         101
#
#   country country_code  phone_code  \
# 0   India           IN          91
# 1   India           IN          91
# 2   India           IN          91
# 3   India           IN          91
# 4   India           IN          91
#
#                                          Location
# 0   Bombuflat, Andaman and Nicobar Islands, India
# 1  Garacharma, Andaman and Nicobar Islands, India
# 2  Port Blair, Andaman and Nicobar Islands, India
# 3      Rangat, Andaman and Nicobar Islands, India
# 4                  Addanki, Andhra Pradesh, India

# %%
locations = locations.fillna('')
locations[locations['state'].astype('str').str.contains('Denbighshire')]
# Out:
#        city_id     city  state_id         state  country_id         country  \
# 41544    41520  Denbigh      3828  Denbighshire         230  United Kingdom
#
#       country_code  phone_code                               Location
# 41544           GB          44  Denbigh, Denbighshire, United Kingdom

# %%
fuzz.WRatio('Denbighshire', 'denbighshire county')
# Out:
# 90
